# %%
# !pip install -U python-jobspy

# %%
import csv
from jobspy import scrape_jobs

jobs = scrape_jobs(
    site_name=["indeed", "linkedin", "zip_recruiter", "google"], # "glassdoor", "bayt", "naukri", "bdjobs"
    search_term="python developer",
    google_search_term="python developer jobs near Hyderabad, India since yesterday",
    location="Hyderabad, India",
    results_wanted=20,
    hours_old=150,
    country_indeed='India',
    
    # linkedin_fetch_description=True # gets more info such as description, direct job url (slower)
    # proxies=["208.195.175.46:65095", "208.195.175.45:65095", "localhost"],
)
print(f"Found {len(jobs)} jobs")
print(jobs.head())
jobs.to_csv("jobs.csv", quoting=csv.QUOTE_NONNUMERIC, escapechar="\\", index=False) # to_excel
# Out:
# Found 40 jobs
#                     id    site  \
# 0  in-d3d326313da0deef  indeed
# 1  in-732300b0cf634b4b  indeed
# 2  in-78bd4057ea68d68e  indeed
# 3  in-a5b78063576ad1f0  indeed
# 4  in-3b31cee64d239a63  indeed
#
#                                              job_url  \
# 0  https://in.indeed.com/viewjob?jk=d3d326313da0deef
# 1  https://in.indeed.com/viewjob?jk=732300b0cf634b4b
# 2  https://in.indeed.com/viewjob?jk=78bd4057ea68d68e
# 3  https://in.indeed.com/viewjob?jk=a5b78063576ad1f0
# 4  https://in.indeed.com/viewjob?jk=3b31cee64d239a63
#
#                                       job_url_direct  \
# 0                          https://aistrata.com/jobs
# 1                          https://aistrata.com/jobs
# 2  https://jobs.dayforcehcm.com/en-US/signantheal...
# 3  https://usijobs.deloitte.com/en_US/careersUSI/...
# 4  https://careers.wipro.com/job/DEVELOPER-L4/154...
#
#                                                title  \
# 0                                 AI Agent Developer
# 1               Software Developer - Java/PHP/Python
# 2          Senior Platform Engineer - Technology R&D
# 3  Gen AI MS Copilot Studio- Senior Analyst- Hyde...
# 4                                       DEVELOPER L4
#
#                          company location date_posted  job_type salary_source  \
# 0  AIStrata Technology Solutions   TS, IN  2026-03-30       NaN          None
# 1  AIStrata Technology Solutions   TS, IN  2026-03-30       NaN          None
# 2                 Signant Health   TS, IN  2026-03-30  fulltime          None
# 3                       Deloitte   TS, IN  2026-03-30       NaN          None
# 4                          Wipro   TS, IN  2026-03-30       NaN          None
#
#    ... company_addresses company_num_employees       company_revenue  \
# 0  ...               NaN                   NaN                   NaN
# 1  ...               NaN                   NaN                   NaN
# 2  ...     Blue Bell, PA        1,001 to 5,000      Decline to state
# 3  ...      New York, NY               10,000+  more than $10B (USD)
# 4  ...         Bengaluru               10,000+     $5B to $10B (USD)
#
#                                  company_description  skills experience_range  \
# 0                                                NaN    None             None
# 1                                                NaN    None             None
# 2  We develop and support innovative technology s...    None             None
# 3                                                       None             None
# 4                                                       None             None
#
#   company_rating company_reviews_count vacancy_count work_from_home_type
# 0           None                  None          None                None
# 1           None                  None          None                None
# 2           None                  None          None                None
# 3           None                  None          None                None
# 4           None                  None          None                None
#
# [5 rows x 34 columns]
